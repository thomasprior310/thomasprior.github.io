# %%
#Using Python for Correlation

#Import all libraries needed

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

#%matplotlib.inline
matplotlib.rcParams['figure.figsize'] = (12,8)

df = pd.read_csv(r"C:\Users\thoma\Downloads\PgaData_2010.csv")
df = df.dropna()
df

# %%
# Scatter plot for wins & SG: OTT

plt.scatter(x=df['Wins'], y=df['SG:OTT'])
plt.title('Wins vs Strokes Gained Off The Tee')

plt.xlabel('Number of Wins')
plt.ylabel('Strokes Gained Off The Tee')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df = df.drop(columns=[ "Year"])

# %%
# Plot the wins vs sg:ott using seaborn


sns.regplot(x='Wins', y='SG:OTT', data=df, scatter_kws={'color': 'red'}, line_kws={'color':'blue'})
plt.title('Wins vs Strokes Gained Off The Tee 2010')
plt.xlabel('Number of Wins')
plt.ylabel("Strokes Gained Off The Tee")
# Out:
# Text(0, 0.5, 'Strokes Gained Off The Tee')

# %%
#Scatter plot for Wins and SG:APR

plt.scatter(x=df['Wins'], y=df['SG:APR'])
plt.title('Wins vs Strokes Gained on Approach')

plt.xlabel('Number of Wins')
plt.ylabel('Strokes Gained on Approach')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot the wins vs sg apr using seaborn

sns.regplot(x='Wins', y='SG:OTT', data=df, scatter_kws={'color': 'red'}, line_kws={'color':'blue'})
plt.title('Wins vs Strokes Gained Off The Tee 2010')
plt.xlabel('Number of Wins')
plt.ylabel("Strokes Gained Off The Tee")
# Out:
# Text(0, 0.5, 'Strokes Gained Off The Tee')

# %%
#Scatter plot for Wins and SG:ARG

plt.scatter(x=df['Wins'], y=df['SG:ARG'])
plt.title('Wins vs Strokes Gained Around the Green')

plt.xlabel('Number of Wins')
plt.ylabel('Strokes Gained Around the Green')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot the wins vs sg arg using seaborn

sns.regplot(x='Wins', y='SG:ARG', data=df, scatter_kws={'color': 'red'}, line_kws={'color':'blue'})
# Out:
# <Axes: xlabel='Wins', ylabel='SG:ARG'>

# %%
#Scatter plot for Wins and Average SG Putting

plt.scatter(x=df['Wins'], y=df['Average SG Putts'])
plt.title('Wins vs Strokes Gained Putting')

plt.xlabel('Number of Wins')
plt.ylabel('Strokes Gained Putting')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Plot the wins vs sg putting

sns.regplot(x='Wins', y='Average SG Putts', data=df, scatter_kws={'color': 'red'}, line_kws={'color':'blue'})
# Out:
# <Axes: xlabel='Wins', ylabel='Average SG Putts'>

# %%
#Correlations matrix
df.corr()
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_15740\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                       Rounds  Fairway Percentage  Year  Avg Distance  \
# Rounds              1.000000            0.138341   NaN     -0.043108
# Fairway Percentage  0.138341            1.000000   NaN     -0.584886
# Year                     NaN                 NaN   NaN           NaN
# Avg Distance       -0.043108           -0.584886   NaN      1.000000
# gir                 0.257671            0.304387   NaN      0.262611
# Average Putts      -0.199485            0.091583   NaN      0.253524
# Average Scrambling  0.319339            0.274876   NaN     -0.232957
# Average Score      -0.411157           -0.169134   NaN     -0.150627
# ...

# %%
#Heatmap matrix

correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot=True)

plt.show

plt.title('Heat Map for Golf Statistics 2010')

plt.xlabel('Golf Stats')
plt.ylabel('Golf Stats')
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_15740\2192493416.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
# Text(120.5815972222222, 0.5, 'Golf Stats')

# %%
#Import libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

#%matplotlib.inline
matplotlib.rcParams['figure.figsize'] = (12,8)

df = pd.read_csv(r"C:\Users\thoma\Downloads\PGAtour_Data_2017.csv")
df
# Out:
#                 Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 0    Bryson DeChambeau             24    5617               3
# 1         Bubba Watson             22    2277               3
# 2       Dustin Johnson             18    3289               3
# 3        Justin Thomas             21    3084               3
# 4        Brooks Koepka             15    2551               2
# ..                 ...            ...     ...             ...
# 190  Xander Schauffele             25    1109               0
# 191       Xinjun Zhang             28     195               0
# 192          Zac Blair             20     176               0
# 193       Zach Johnson             24     890               0
# 194        Zecheng Dou             23      21               0
#
#      NUMBER_OF_TOP_Tens  SG_PUTTING_PER_ROUND  AVG_Driving_DISTANCE  \
# 0                     9                 0.326                 306.4
# 1                     6                -0.033                 313.6
# ...

# %%
# Data types for our columns

df.dtypes
# Out:
# Player                     object
# EVENTS_PLAYED               int64
# POINTS                      int64
# NUMBER_OF_WINS              int64
# NUMBER_OF_TOP_Tens          int64
# SG_PUTTING_PER_ROUND      float64
# AVG_Driving_DISTANCE      float64
# SG_PER_ROUND              float64
# SG:OTT                    float64
# SG:APR                    float64
# SG:ARG                    float64
# SG_PUTTING_PER_ROUND.1    float64
# AVG_SCORE                 float64
# HOLES_PLAYED                int64
# AGE                         int64
# Unnamed: 15               float64
# dtype: object

# %%
df = df.drop(columns=[ "Unnamed: 15"])

# %%
#Exploring the potential correlation between wins in a season and strokes gained off the tee

# %%
# Scatter plot for wins & SG: OTT

plt.scatter(x=df['NUMBER_OF_WINS'], y=df['SG:OTT'])
plt.title('Wins vs Strokes Gained Off The Tee')

plt.xlabel('Wins')
plt.ylabel('Strokes Gained Off The Tee')

plt.show

#Players with the most wins were very good drivers of the golfball
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot the budget vs gross using seaborn

sns.regplot(x='NUMBER_OF_WINS', y='SG:OTT', data=df, scatter_kws={'color': 'red'}, line_kws={'color':'blue'})
plt.title('Wins vs Strokes Gained Off The Tee 2017')
plt.xlabel('Wins')
plt.ylabel('Strokes Gained Off The Tee')
# Out:
# Text(0, 0.5, 'Strokes Gained Off The Tee')

# %%
#Scatter plot for Wins and SG:APR

plt.scatter(x=df['NUMBER_OF_WINS'], y=df['SG:APR'])
plt.title('Wins vs Strokes Gained on Approach')

plt.xlabel('Wins')
plt.ylabel('Strokes Gained on Approach')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot the wins vs sg apr using seaborn

sns.regplot(x='NUMBER_OF_WINS', y='SG:APR', data=df, scatter_kws={'color': 'red'}, line_kws={'color':'blue'})
plt.title('Wins vs Strokes Gained on Approach 2017')
plt.xlabel('Wins')
plt.ylabel('Strokes Gained on Approach')
# Out:
# Text(0, 0.5, 'Strokes Gained on Approach')

# %%
#Scatter plot for Wins and SG:ARG

plt.scatter(x=df['NUMBER_OF_WINS'], y=df['SG:ARG'])
plt.title('Wins vs Strokes Gained Around the Green')

plt.xlabel('Number of Wins')
plt.ylabel('Strokes Gained Around the Green')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot the wins vs sg arg using seaborn

sns.regplot(x='NUMBER_OF_WINS', y='SG:ARG', data=df, scatter_kws={'color': 'red'}, line_kws={'color':'blue'})
# Out:
# <Axes: xlabel='NUMBER_OF_WINS', ylabel='SG:ARG'>

# %%
#Scatter plot for Wins and SG: Putting

plt.scatter(x=df['NUMBER_OF_WINS'], y=df['SG_PUTTING_PER_ROUND'])
plt.title('Wins vs Strokes Gained Putting')

plt.xlabel('Number of Wins')
plt.ylabel('Strokes Gained Putting')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Plot the wins vs sg putting

sns.regplot(x='NUMBER_OF_WINS', y='SG_PUTTING_PER_ROUND', data=df, scatter_kws={'color': 'red'}, line_kws={'color':'blue'})
# Out:
# <Axes: xlabel='NUMBER_OF_WINS', ylabel='SG_PUTTING_PER_ROUND'>

# %%
#Heatmap correlation matrix

df.corr()

correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot=True)

plt.show

plt.title('Heat Map for Golf Statistics 2017')

plt.xlabel('Golf Stats')
plt.ylabel('Golf Stats')
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_15740\2638565108.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_15740\2638565108.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
# Text(120.5815972222222, 0.5, 'Golf Stats')
